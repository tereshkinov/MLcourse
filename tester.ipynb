# %%
import pandas as pd
data = pd.Series(1, index=['a', 'b', 'c', 'd'])
data
# Out:
# a    1
# b    1
# c    1
# d    1
# dtype: int64

# %%
range(1, 4)
# Out:
# range(1, 4)

# %%
weights = pd.Series(1, index=list(range(0,5 + 1)))
weights
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# dtype: int64

# %%
dict = {'oleg': 1, 'grisha': 1}
pddict= pd.Series(dict)
pddict, pddict['oleg']
# Out:
# (oleg      1
#  grisha    2
#  dtype: int64,
#  np.int64(1))

# %%
X = pd.DataFrame([[1,1,1,1],[11,11,11,11], [111,111,111,111]])
X
# Out:
#      0    1    2    3
# 0    1    1    1    1
# 1   11   11   11   11
# 2  111  111  111  111
